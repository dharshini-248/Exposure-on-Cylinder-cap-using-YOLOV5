# %% [markdown]
# <a href="https://colab.research.google.com/github/dharshini-248/Exposure-on-Cylinder-cap-using-YOLOV5/blob/main/EXPOSURE_ON_CYLINDER_CAP_DETECTION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5  #clone
# %cd yolov5
# %pip install -qr requirements.txt  #install
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12711, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 12711 (delta 2), reused 12 (delta 0), pack-reused 12694
# Receiving objects: 100% (12711/12711), 11.69 MiB | 29.05 MiB/s, done.
# Resolving deltas: 100% (8857/8857), done.
# /content/yolov5
#      |████████████████████████████████| 596 kB 5.4 MB/s

# %%
import  torch
from IPython.display import Image,clear_output

clear_output()

# %%
#!unzip -q ../train_data.zip -d ../

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# exp4 =>poch=220 batch=64 imgae=320
#exp5 =>epoch=300 batch=64 image=320
#exp6 =>epoch=350 batch=64 image=320

# %%
#!python train.py --img 320 --batch 64 --epochs 350 --data custom_data.yaml --weights yolov5s.pt --cache
# Out:
# ...
# train: weights=yolov5s.pt, cfg=, data=custom_datal.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=350, batch_size=64, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-1-g66aaf51 torch 1.10.0+cu111 CPU
#
# ...

# %%
# !python detect.py --weights /content/yolov5/cylinder.pt --img 320 --conf 0.25 --source ../cylinder.mp4
# Out:
# ...
# detect: weights=['/content/yolov5/cylinder.pt'], source=../cylinder.mp4, data=data/coco128.yaml, imgsz=[320, 320], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-117-g698a5d7 torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/900) /content/cylinder.mp4: 192x320 1 without cap, Done. (0.073s)
# video 1/1 (2/900) /content/cylinder.mp4: 192x320 1 without cap, Done. (0.063s)
# video 1/1 (3/900) /content/cylinder.mp4: 192x320 1 without cap, Done. (0.061s)
# video 1/1 (4/900) /content/cylinder.mp4: 192x320 1 without cap, Done. (0.071s)
# ...
